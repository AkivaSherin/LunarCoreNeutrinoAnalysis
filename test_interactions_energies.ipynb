# %%
import importlib
lunar_neutrino_lib = importlib.import_module("lunar_neutrino_lib")
importlib.reload(lunar_neutrino_lib)
from lunar_neutrino_lib import *
import numpy as np

log_energies = np.linspace(-2, 1.0, 100)

plt.figure()
plt.plot(log_energies, get_diff_interactions(log_energies))
plt.xlabel("Energy (log GeV)")
plt.yscale("log")
plt.ylabel("interactions (per second I am pretty sure)")
plt.show()

# %%
import importlib
lunar_neutrino_lib = importlib.import_module("lunar_neutrino_lib")
importlib.reload(lunar_neutrino_lib)
from lunar_neutrino_lib import *
import numpy as np
import matplotlib.pyplot as plt

plt.figure()

ratios = [1, 5, 15]
fixed_radius = 600
log_energies = np.linspace(-1, 1, 10) # log GeV

for ratio in ratios:
    pdf = muon_pdf_spline(ratio, fixed_radius)
    plt.plot(log_energies, pdf(log_energies), label=str(ratio))

plt.xlabel("Energy (log GeV)")
plt.ylabel("Probability")
plt.title("Muon detection PDF for core radius = " + str(fixed_radius) + " km")
plt.legend(title="Density Ratios")
plt.savefig("muon_detection_pdfs_by_ratios_radius" + str(fixed_radius) + ".png")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/Summer_Reasearch/PhysNotebooks/lunar_neutrino_lib.py:214
#     213 try:
# --> 214     with open('muon-pdf-splines-catalog.pkl', 'rb') as f:
#     215         muon_pdf_splines_catalog = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'muon-pdf-splines-catalog.pkl'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 import importlib
#       2 lunar_neutrino_lib = importlib.import_module("lunar_neutrino_lib")
# ----> 3 importlib.reload(lunar_neutrino_lib)
#       4 from lunar_neutrino_lib import *
#       5 import numpy as np
#
# File ~/miniconda3/lib/python3.12/importlib/__init__.py:131, in reload(module)
#     129 if spec is None:
#     130     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 131 _bootstrap._exec(spec, module)
#     132 # The module may have replaced itself in sys.modules!
#     133 return sys.modules[name]
#
# File <frozen importlib._bootstrap>:866, in _exec(spec, module)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Desktop/Summer_Reasearch/PhysNotebooks/lunar_neutrino_lib.py:220
#     217 muon_pdf_splines_catalog = dict()
#     218 #this is slow but should only happen once
# --> 220 starter_muon_pdf = make_muon_detections_pdf(1, 330)
#     221 muon_pdf_splines_catalog['core_mantle_density_ratio'] = [1]
#     222 muon_pdf_splines_catalog['core_radius'] = [330]
#
# File ~/Desktop/Summer_Reasearch/PhysNotebooks/lunar_neutrino_lib.py:192, in make_muon_detections_pdf(core_mantle_density_ratio, core_radius)
#     189 for log_energy in log_energies:
#     190     neutrinos_detected_ignoring_oscillation = get_diff_interactions(log_energy)  # this is per log GeV
#     191     actual_muons_detected = neutrinos_detected_ignoring_oscillation * \
# --> 192                             monte_carlo_uniform_core(10 ** log_energy, core_mantle_density_ratio, core_radius)[
#     193                                 1]  # factors in expected flavor ratio
#     194     detection_rate.append(actual_muons_detected)
#     196 detections_interp = interp1d(log_energies, detection_rate, kind='linear')
#
# File ~/Desktop/Summer_Reasearch/PhysNotebooks/lunar_neutrino_lib.py:731, in monte_carlo_uniform_core(energy, core_mantle_density_ratio, core_radius)
#     729 after_moon = three_flavor_prob_any_moon_density(energy, radius, 0, density_function)
#     730 e_prob += after_moon[1][-1] * radius
# --> 731 m_prob += after_moon[2][-1] * radius
#     732 t_prob += after_moon[3][-1] * radius
#     733 scale_factor += radius
#
# File ~/Desktop/Summer_Reasearch/PhysNotebooks/lunar_neutrino_lib.py:709, in three_flavor_prob_any_moon_density(energy, y, z, density_function)
#     706 del13 = np.pi / 3
#     707 solution = odeint(moon_deriv_three_flavor, turn_flavor_ratios_into_probability_amplitudes(2), x,
#     708                   args=(energy, del13, y, z, density_function))
# --> 709 ProbNuE = solution[:, 0] * solution[:, 0] + solution[:, 1] * solution[:, 1]
#     710 ProbNuMu = solution[:, 2] * solution[:, 2] + solution[:, 3] * solution[:, 3]
#     711 ProbNuTau = solution[:, 4] * solution[:, 4] + solution[:, 5] * solution[:, 5]
#
# File ~/miniconda3/lib/python3.12/site-packages/scipy/integrate/_odepack_py.py:243, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     241 t = copy(t)
#     242 y0 = copy(y0)
# --> 243 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     244                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     245                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     246                          int(bool(tfirst)))
#     247 if output[-1] < 0:
#     248     warning_msg = (f"{_msgs[output[-1]]} Run with full_output = 1 to "
#     249                    f"get quantitative information.")
#
# File ~/Desktop/Summer_Reasearch/PhysNotebooks/lunar_neutrino_lib.py:652, in moon_deriv_three_flavor(amp, x, E_GeV, del13, y, z, density_function)
#     650 c12 = np.cos(Th12)
#     651 s23 = np.sin(Th23)
# --> 652 c23  = np.cos(Th23)
#     653 s13 = np.sin(Th13)
#     654 c13 = np.cos(Th13)
#
# KeyboardInterrupt:
