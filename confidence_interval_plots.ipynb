# %%
# %run mock_data_analysis.ipynb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /var/folders/dr/tnb6gyns3kl9xhswdbqkpm_00000gn/T/ipykernel_50938/777307116.py:8
#       6 from scipy.integrate import odeint, quad
#       7 import math
# ----> 8 import pandas as pd
#       9 from scipy.interpolate import interp1d
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/__init__.py:49
#      46 # let init-time option registration happen
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#      52     Int8Dtype,
#      53     Int16Dtype,
#      54     Int32Dtype,
#      55     Int64Dtype,
#      56     UInt8Dtype,
#      57     UInt16Dtype,
#      58     UInt32Dtype,
#      59     UInt64Dtype,
#      60     Float32Dtype,
#      61     Float64Dtype,
#      62     CategoricalDtype,
# ...

# %%
rats, rads, stats, min_stat = make_confidence_interval_data(50, make_mock_data(5, 330, 10))
make_confidence_interval_contour_plot(rats, rads, stats,  min_stat) #could make continuous
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rats, rads, stats, min_stat = make_confidence_interval_data(50, make_mock_data(5, 330, 10))
#       2 make_confidence_interval_contour_plot(rats, rads, stats,  min_stat)
#
# NameError: name 'make_confidence_interval_data' is not defined
